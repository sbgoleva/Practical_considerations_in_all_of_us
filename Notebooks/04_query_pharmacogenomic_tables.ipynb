# %%
# !pip install polars

# %%
import json
import subprocess
import re
import polars as pl

# %%
def wb(*args):
    """Run a wb command and return parsed JSON."""
    cmd = ["wb", *args, "--format=json"]
    result = subprocess.check_output(cmd, text=True)
    return json.loads(result)

# %%
# Get workspace info
workspace = wb("workspace", "describe")
GOOGLE_CLOUD_PROJECT = workspace["googleProjectId"]

# %%
#"dataproc" for dataproc environments, "jupyter" for regular environments
#as file paths sometimes change, may need to go into file layout and update directory
high_conf_prefix = "/home/dataproc/workspace/cdrv9/vwb-aou-datasets-controlled-v9/v9/wgs/short_read/snpindel/aux/pgx/high_concordance/"
low_conf_prefix = "/home/dataproc/workspace/cdrv9/vwb-aou-datasets-controlled-v9/v9/wgs/short_read/snpindel/aux/pgx/low_concordance/"

# %% [markdown]
# # CYP2C_Cluster

# %%
# Read the TSV file into a Polars DataFrame
CYP2C_df = pl.read_csv(f"{high_conf_prefix}2c_cluster_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = CYP2C_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # show all rows
print(grouped_counts)

# %% [markdown]
# # ABCG2

# %%
# Read the TSV file into a Polars DataFrame
ABCG2_df = pl.read_csv(f"{high_conf_prefix}abcg2_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = ABCG2_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # show all rows
print(grouped_counts)

# %% [markdown]
# # CACNA1S

# %%
CACNA1S_df = pl.read_csv(
    f"{high_conf_prefix}cacna1s_cohort_results.tsv",
    separator="\t",
    null_values=["n/a"]
)

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = CACNA1S_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1) # Don't print counts <20

# %%
phenotype_counts = (
    CACNA1S_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # CFTR

# %%
# Read the TSV file into a Polars DataFrame
CFTR_df = pl.read_csv(f"{high_conf_prefix}cftr_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = CFTR_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    CFTR_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # CYP2D6

# %%
# Read the TSV file into a Polars DataFrame
CYP2D6_df = pl.read_csv(f"{high_conf_prefix}cyp2d6_cohort_foxtrot_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = CYP2D6_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    CYP2D6_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # G6PD

# %%
# Read the TSV file into a Polars DataFrame
G6PD_df = pl.read_csv(f"{high_conf_prefix}g6pd_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = G6PD_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    G6PD_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # NUDT15

# %%
# Read the TSV file into a Polars DataFrame
NUDT15_df = pl.read_csv(f"{high_conf_prefix}nudt15_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = NUDT15_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    NUDT15_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # RYR1

# %%
# Read the TSV file into a Polars DataFrame
RYR1_df = pl.read_csv(f"{high_conf_prefix}ryr1_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = RYR1_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    RYR1_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .filter(pl.col("count") >= 20)
    .sort("count", descending=True)
)

print(phenotype_counts) #Don't print counts <20

# %% [markdown]
# # TPMT

# %%
# Read the TSV file into a Polars DataFrame
TPMT_df = pl.read_csv(f"{high_conf_prefix}tpmt_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = TPMT_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    TPMT_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # VKORC1

# %%
# Read the TSV file into a Polars DataFrame
VKORC1_df = pl.read_csv(f"{high_conf_prefix}vkorc1_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = VKORC1_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20
print(grouped_counts)

# %%
phenotype_counts = (
    VKORC1_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts) #Note that variant present includes both hom and het counts

# %% [markdown]
# # CYP2B6

# %%
# Read the TSV file into a Polars DataFrame
CYP2B6_df = pl.read_csv(f"{high_conf_prefix}cyp2b6_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = CYP2B6_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    CYP2B6_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # CYP2C19

# %%
# Read the TSV file into a Polars DataFrame
CYP2C19_df = pl.read_csv(f"{low_conf_prefix}cyp2c19_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = CYP2C19_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    CYP2C19_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # CYP3A5

# %%
# Read the TSV file into a Polars DataFrame
CYP3A5_df = pl.read_csv(f"{high_conf_prefix}cyp3a5_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = CYP3A5_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    CYP3A5_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .filter(pl.col("count") >= 20) #Don't print counts <20
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # CYP4F2

# %%
# Read the TSV file into a Polars DataFrame
CYP4F2_df = pl.read_csv(f"{high_conf_prefix}cyp4f2_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = CYP4F2_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # show all rows
print(grouped_counts)

# %%
phenotype_counts = (
    CYP4F2_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # DPYD

# %%
# Read the TSV file into a Polars DataFrame
DPYD_df = pl.read_csv(f"{low_conf_prefix}dpyd_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = DPYD_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    DPYD_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # SLCO1B1

# %%
# Read the TSV file into a Polars DataFrame
SLCO1B1_df = pl.read_csv(f"{low_conf_prefix}slco1b1_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = SLCO1B1_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    SLCO1B1_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # UGT1A1

# %%
# Read the TSV file into a Polars DataFrame
UGT1A1_df = pl.read_csv(f"{high_conf_prefix}ugt1a1_cohort_results.tsv", separator="\t")

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = UGT1A1_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    UGT1A1_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)

# %% [markdown]
# # CYP2C9

# %%
# Read the TSV file into a Polars DataFrame
CYP2C9_df = pl.read_csv(f"{high_conf_prefix}cyp2c9_cohort_results.tsv", separator="\t", null_values=["n/a", "NA", ""],)

# %%
# Group by 'gene' and 'genotype' and count the occurrences
grouped_counts = CYP2C9_df.group_by(["gene", "genotype", "phenotype"]).agg(pl.len())

# Print the entire Polars DataFrame
pl.Config.set_tbl_rows(-1)  # Don't print counts <20

# %%
phenotype_counts = (
    CYP2C9_df
    .group_by("phenotype")
    .agg(pl.len().alias("count"))
    .sort("count", descending=True)
)

print(phenotype_counts)
